# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
vote_reg_df = pd.read_csv("voting_registration.csv")

vote_reg_df.set_index('STATE', inplace=True)

vote_reg_df.drop('UNITED STATES', axis=0, inplace=True)

vote_reg_df_cleaned=vote_reg_df[['Total Population', 'Total Citizen Population', 'Total registered', 'Total voted']]

v_number=vote_reg_df_cleaned.apply(lambda x: x.str.replace(',', '').astype(float), axis=1)

# %%
v_number.apply(pd.to_numeric, errors='coerce')
# Out:
#                       Total Population  Total Citizen Population  \
# STATE
# ALABAMA                         3717.0                    3651.0
# ALASKA                           518.0                     502.0
# ARIZONA                         5196.0                    4585.0
# ARKANSAS                        2216.0                    2116.0
# CALIFORNIA                     29894.0                   24890.0
# COLORADO                        4242.0                    3895.0
# CONNECTICUT                     2759.0                    2483.0
# DELAWARE                         729.0                     669.0
# DISTRICT OF COLUMBIA             553.0                     512.0
# FLORIDA                        16202.0                   14428.0
# GEORGIA                         7626.0                    7048.0
# HAWAII                          1064.0                     974.0
# IDAHO                           1224.0                    1150.0
# ...

# %%
v_number['Percent Registered']=v_number['Total registered']/v_number['Total Citizen Population']
v_number['Percent Voted']=v_number['Total voted']/v_number['Total Citizen Population']
v_number.head()

# %%
from config import username
from config import password

# %%
engine = create_engine(f'postgresql://postgres:password@localhost:5432/voting_db')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
v_number.to_sql(name='registration',con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...
